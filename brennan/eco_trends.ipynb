# %% [markdown]
# # Modeling economic trends

# %% [markdown]
# ### Project ~ predict market trends one day into the future.

# %% [markdown]
# Current status: Models are still close to a coin flip for predicting 1 day into the future, but results are more enouraging for predicting whether or not the S&P 500 will rise or fall 10-90 days out.

# %% [markdown]
# ### Getting the data (see quandl.com)

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import Quandl 

print 'versions:'
print 'numpy', np.__version__
print 'pandas', pd.__version__
print 'skLearn', sk.__version__
print 'matplotlib', matplotlib.__version__
print 'Quandl', Quandl.__version__
# Out:
# versions:
# numpy 1.9.1
# pandas 0.14.1
# skLearn 0.15.2
# matplotlib 1.4.0
# Quandl 2.8.5

# %% [markdown]
# ### Locate daily indices representative of market forces:

# %%
#see Quandl.com
gold = "FRED/GOLDPMGBD228NLBM" #since 1968
oil = "DOE/RWTC" #since 1986
rates = "FRED/DFF" #federal interest rates since 1954
stock = "YAHOO/INDEX_GSPC" #since 1950
dollar = "FRED/DTWEXM" #since 1973
force = [rates, dollar, gold, oil]

# %%
recession = "FRED/RECPROUSM156N"
inflation = "RATEINF/INFLATION_USA"
productivity = "FRED/OPHNFB" #new economy theory
costs = "FRED/PRS88003203" #consider outputPerHour / unitCosts
indicator = [recession, inflation, productivity, costs]

# %% [markdown]
# ### Load dataframe, check row length and clean up column names

# %%
token = ""
stock = Quandl.get(stock, authtoken=token, trim_start='1987-01-02')
forces = Quandl.get(force, authtoken=token, trim_start='1987-01-02')
indicators = Quandl.get(indicator, authtoken=token, trim_start='1987-01-02')

# %%
print 'stock rows: %d, force rows: %d, indicator rows: %d' % (len(stock), len(forces), len(indicators))
# Out:
# stock rows: 7090, force rows: 10272, indicator rows: 669

# %%
df = stock.copy()
#df.head()

# %%
stock_tags = ['open', 'high', 'low', 'close', 'vol', 'adjc']     
stock_tag = ['snp_' + i for i in stock_tags] #for i in tickers]
stock_columns = dict(zip(list(stock.columns.values), stock_tag))
print stock_columns
# Out:
# {'Volume': 'snp_vol', 'Adjusted Close': 'snp_adjc', 'High': 'snp_high', 'Low': 'snp_low', 'Close': 'snp_close', 'Open': 'snp_open'}

# %%
df.rename(columns=stock_columns, inplace=True)
df.head()
# Out:
#             snp_open  snp_high  snp_low  snp_close    snp_vol  snp_adjc
# Date
# 1987-01-02    242.17    246.45   242.17     246.45   91880000    246.45
# 1987-01-05    246.45    252.57   246.45     252.19  181900000    252.19
# 1987-01-06    252.20    253.99   252.14     252.78  189300000    252.78
# 1987-01-07    252.78    255.72   252.65     255.33  190900000    255.33
# 1987-01-08    255.36    257.28   254.97     257.28  194500000    257.28

# %%
stock_stats = df.describe()
stock_stats
# Out:
#           snp_open     snp_high      snp_low    snp_close       snp_vol  \
# count  7090.000000  7090.000000  7090.000000  7090.000000  7.090000e+03
# mean    955.241100   961.331228   948.804336   955.507457  1.723266e+09
# std     465.997577   468.621320   463.247228   466.098366  1.755569e+09
# min     223.980000   225.770000   216.460000   223.920000  1.499000e+07
# 25%     456.502500   458.122500   454.525000   456.537500  2.770275e+08
# 50%    1064.765000  1072.415000  1056.640000  1064.880000  1.080050e+09
# 75%    1304.720000  1312.585000  1294.892500  1304.882500  2.953192e+09
# max    2096.470000  2101.300000  2089.800000  2100.340000  1.145623e+10
#
#           snp_adjc
# count  7090.000000
# mean    955.507457
# std     466.098366
# min     223.920000
# 25%     456.537500
# 50%    1064.880000
# 75%    1304.882500
# max    2100.340000

# %%
def kill_nulls(dframe):
    start_len = len(dframe)
    if dframe.isnull().sum().max() > 0:
        print 'dropped these nulls:'
        print dframe.isnull().sum()
        dframe.dropna(inplace=True)
        print 'dataframe length went from %d to %d' % (start_len, len(dframe))
    else:
        print 'no nulls, dataframe length %d' % (start_len)
    return dframe

# %%
#df = kill_nulls(df)
kill_nulls(df)
''
# Out:
# no nulls, dataframe length 7090
# ''

# %% [markdown]
# ### Using logistic regression, testing the importance of the stand-alone S&P data before adding other features

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn import metrics

# %%
def make_Xy_shift(dframe, target, period): #, allfeatures):    
    features = list(dframe.columns.values)
    Xy = dframe.copy()
    Xy = kill_nulls(Xy)
    tag = target + '-' + str(period)
    Xy[tag] = Xy[target].shift(-period)
    binTag = tag + '-bin'
    Xy[binTag] = np.where(Xy[tag] > Xy[target], 1, 0)
    df_X = Xy.ix[:-1][features]
    #if allfeatures:
    #    df_X = Xy.ix[:-1][list(dframe.columns.values)]
    #else:
    #    df_X = Xy.ix[:-1][target]
    df_y = Xy.ix[:-1][tag]
    df_yBin = Xy.ix[:-1][binTag]
    return df_X, df_y, df_yBin

# %%
dfX, y, yBin = make_Xy_shift(df, 'snp_close', 1)
len(dfX)
# Out:
# no nulls, dataframe length 7090
# 7089

# %%
X_train, X_test, y_train, y_test = train_test_split(dfX, yBin, test_size=0.3, random_state=1)
print X_train.shape, X_test.shape, y_train.shape, y_test.shape

lr = LogisticRegression()
# Out:
# (4962, 6) (2127, 6) (4962,) (2127,)

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
preds = lr.predict(X_test)

#lr.score(X_test, y_test)
cm = metrics.confusion_matrix(y_test, preds)

probs = lr.predict_proba(X_test)[:, 1]
ra_score = metrics.roc_auc_score(y_test, probs)
col = list(dfX.columns.values)

# %%
def plot_rocauc(y_tester, probabs): #, info): #, ra_score, cm, col):
    fpr, tpr, thresholds = metrics.roc_curve(y_tester, probabs)
    plt.plot(fpr, tpr)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Pos. Rate (1 - Specificity)')
    plt.ylabel('True Pos. Rate (Sensitivity)')
    #plt.title(info)
    #props = dict(boxstyle='round', facecolor='white', alpha=0.5)
    #plt.text(0.87, 0.75, ra_score, fontsize=14, bbox=props)
    #plt.text(0.65, 0.1, cm, fontsize=14, bbox=props)
    #plt.legend(col, loc='upper center', bbox_to_anchor=(1.6, 1),
    #           ncol=6, fancybox=True, shadow=True)

# %% [markdown]
# ### Close to a coin flip:

# %%
print col
print ra_score
print cm
plot_rocauc(y_test, probs) #, 'Using 6 rows of S&P data') #, ra_score, cm, col)

#print lr.predict_proba(X_test)[:, 1].mean()
# Out:
# ['snp_open', 'snp_high', 'snp_low', 'snp_close', 'snp_vol', 'snp_adjc']
# 0.506423882019
# [[   0  988]
#  [   0 1139]]

# %%
yBin.mean()
# Out:
# 0.53858089998589365

# %%
lr = LogisticRegression()
lr.fit(dfX, yBin)
#cv_scores = cross_val_score()
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
#doing it right??
cross_val_score(lr, dfX, y=yBin, cv=3, scoring='accuracy')
# Out:
# array([ 0.53849408,  0.53872196,  0.53852667])

# %%
preds = lr.predict(dfX)

# %%
lr.score(dfX, yBin)
# Out:
# 0.53858089998589365

# %%
cm = metrics.confusion_matrix(yBin, preds)

probs = lr.predict_proba(dfX)[:, 1]
score = metrics.roc_auc_score(yBin, probs)

# %%
lr.predict_proba(dfX)
# Out:
# array([[ 0.49891071,  0.50108929],
#        [ 0.49784347,  0.50215653],
#        [ 0.49775574,  0.50224426],
#        ...,
#        [ 0.45746006,  0.54253994],
#        [ 0.45520714,  0.54479286],
#        [ 0.45827711,  0.54172289]])

# %%
plot_rocauc(yBin, probs) #, 'Using 6 rows of S&P data')
col = list(dfX.columns.values)
print col
print score 
print cm
#if less than (yBin.mean() = ).538, then is bad
# Out:
# ['snp_open', 'snp_high', 'snp_low', 'snp_close', 'snp_vol', 'snp_adjc']
# 0.500624045235
# [[   0 3271]
#  [   0 3818]]

# %%
dfX, y, yBin = make_Xy_shift(df, 'snp_close', 1)
len(dfX)
# Out:
# no nulls, dataframe length 7090
# 7089

# %%
def train_test_split_logreg_plot(X_data, y_data, info):
    col = list(X_data.columns.values)
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=1)
    lr = LogisticRegression()
    lr.fit(X_train, y_train)
    preds = lr.predict(X_test)
    #lr.score(X_test, y_test)
    cm = metrics.confusion_matrix(y_test, preds)
    probs = lr.predict_proba(X_test)[:, 1]
    score = metrics.roc_auc_score(y_test, probs)
    prob_mean = lr.predict_proba(X_test)[:, 1].mean()
    plot_rocauc(y_test, probs) #, info, score, cm, col)
    print '%s %s' % (info, score)
    print cm

# %%
col = list(dfX.columns.values)
col
# Out:
# ['snp_open', 'snp_high', 'snp_low', 'snp_close', 'snp_vol', 'snp_adjc']

# %% [markdown]
# ### Picking out the most important features - it looks like volume and closing price by a smidge

# %%
for i in col:
    train_test_split_logreg_plot(dfX[[i]], yBin, i)
# Out:
# snp_open 0.498981633864
# [[   0  988]
#  [   0 1139]]
# snp_high 0.499229116385
# [[   0  988]
#  [   0 1139]]
# snp_low 0.498937646846
# [[   0  988]
#  [   0 1139]]
# snp_close 0.499692979494
# [[   0  988]
#  [   0 1139]]
# snp_vol 0.506423882019
# [[   0  988]
#  [   0 1139]]
# snp_adjc 0.499692979494
# [[   0  988]
#  [   0 1139]]

# %% [markdown]
# ### Weighting two features, we add a new feature that multiplies volume by the change in closing prices

# %%
df_cv = df.copy()

# %%
#df_cv['snp_close-shift1'] = df_cv['snp_close'].shift(1)
df_cv['delta.vol'] = (df_cv['snp_close'] - df_cv['snp_close-shift1'].shift(1)) * df_cv['snp_vol']
df_cv.head()
# Out:
#             snp_open  snp_high  snp_low  snp_close    snp_vol  snp_adjc  \
# Date
# 1987-01-02    242.17    246.45   242.17     246.45   91880000    246.45
# 1987-01-05    246.45    252.57   246.45     252.19  181900000    252.19
# 1987-01-06    252.20    253.99   252.14     252.78  189300000    252.78
# 1987-01-07    252.78    255.72   252.65     255.33  190900000    255.33
# 1987-01-08    255.36    257.28   254.97     257.28  194500000    257.28
#
#             snp_close-shift1     delta.vol
# Date
# 1987-01-02               NaN           NaN
# 1987-01-05            246.45  1.044106e+09
# 1987-01-06            252.19  1.116870e+08
# 1987-01-07            252.78  4.867950e+08
# 1987-01-08            255.33  3.792750e+08

# %%
dfX, y, yBin = make_Xy_shift(df_cv, 'snp_close', 1)
len(dfX)
# Out:
# dropped these nulls:
# snp_open            0
# snp_high            0
# snp_low             0
# snp_close           0
# snp_vol             0
# snp_adjc            0
# snp_close-shift1    1
# delta.vol           1
# dtype: int64
# dataframe length went from 7090 to 7089
# 7088

# %%
dfX.head()
# Out:
#             snp_open  snp_high  snp_low  snp_close    snp_vol  snp_adjc  \
# Date
# 1987-01-05    246.45    252.57   246.45     252.19  181900000    252.19
# 1987-01-06    252.20    253.99   252.14     252.78  189300000    252.78
# 1987-01-07    252.78    255.72   252.65     255.33  190900000    255.33
# 1987-01-08    255.36    257.28   254.97     257.28  194500000    257.28
# 1987-01-09    257.26    259.20   256.11     258.73  193000000    258.73
#
#             snp_close-shift1     delta.vol
# Date
# 1987-01-05            246.45  1.044106e+09
# 1987-01-06            252.19  1.116870e+08
# 1987-01-07            252.78  4.867950e+08
# 1987-01-08            255.33  3.792750e+08
# 1987-01-09            257.28  2.798500e+08

# %% [markdown]
# ### And we improve our roc_auc score by 0.02

# %%
col = list(df_cv.columns.values)
for i in col:
    train_test_split_logreg_plot(dfX[[i]], yBin, i)
# Out:
# snp_open 0.492401953377
# [[   0  986]
#  [   0 1141]]
# snp_high 0.492925052399
# [[   0  986]
#  [   0 1141]]
# snp_low 0.492626392634
# [[   0  986]
#  [   0 1141]]
# snp_close 0.493269488883
# [[   0  986]
#  [   0 1141]]
# snp_vol 0.513149473879
# [[   0  986]
#  [   0 1141]]
# snp_adjc 0.493269488883
# [[   0  986]
#  [   0 1141]]
# snp_close-shift1 0.492386842615
# [[   0  986]
#  [   0 1141]]
# delta.vol 0.528006019416
# [[543 443]
#  [587 554]]

# %%
train_test_split_logreg_plot(dfX[['delta.vol']], yBin, 'delta.vol')
# Out:
# delta.vol 0.528006019416
# [[543 443]
#  [587 554]]

# %%
train_test_split_logreg_plot(dfX, yBin, col)
# Out:
# ['snp_open', 'snp_high', 'snp_low', 'snp_close', 'snp_vol', 'snp_adjc', 'snp_close-shift1', 'delta.vol'] 0.5259860661
# [[  34  952]
#  [  33 1108]]

# %% [markdown]
# ### Changing the distance of our prediction from 1 day out to 30 days out, we improve our roc auc score to 0.5599

# %%
dfX, y, yBin = make_Xy_shift(df_cv, 'snp_close', 30)
train_test_split_logreg_plot(dfX, yBin, "")
# Out:
# dropped these nulls:
# snp_open            0
# snp_high            0
# snp_low             0
# snp_close           0
# snp_vol             0
# snp_adjc            0
# snp_close-shift1    1
# delta.vol           1
# dtype: int64
# dataframe length went from 7090 to 7089
# 0.559983865949

# %% [markdown]
# ### Adding in more features like the federal interest rate, and indices for the dollar, gold and oil

# %%
force_tags = ['intRate', 'dollar', 'gold', 'oil']
force_tag = dict(zip(list(forces.columns.values), force_tags))
print force_tag
# Out:
# {u'FRED.GOLDPMGBD228NLBM - Value': 'gold', u'DOE.RWTC - Value': 'oil', u'FRED.DTWEXM - Value': 'dollar', u'FRED.DFF - Value': 'intRate'}

# %%
df_forces = forces.copy()
df_forces.rename(columns=force_tag, inplace=True)
df_forces.head()
# Out:
#             intRate    dollar    gold    oil
# Date
# 1987-01-02     6.46  103.8142  403.50  18.13
# 1987-01-03     6.46       NaN     NaN    NaN
# 1987-01-04     6.46       NaN     NaN    NaN
# 1987-01-05     6.86  104.3439  398.95  17.98
# 1987-01-06     6.56  104.0379  401.70  18.21

# %%
force_stats = df_forces.describe()
force_stats
# Out:
#             intRate       dollar         gold          oil
# count  10269.000000  7069.000000  7055.000000  7091.000000
# mean       3.735608    87.525881   614.717527    43.648182
# std        2.712558    10.092299   424.464206    31.164517
# min        0.040000    67.994400   252.800000    10.820000
# 25%        1.010000    79.941200   347.950000    19.475000
# 50%        4.160000    87.316500   392.500000    27.250000
# 75%        5.570000    94.639200   802.000000    69.090000
# max       10.710000   113.098800  1895.000000   145.310000

# %%
df_forces.fillna(method = 'pad', inplace=True)  
kill_nulls(df_forces)
''
# Out:
# no nulls, dataframe length 10272
# ''

# %%
df = df.join(df_forces, how='left')

# %%
len(df)
# Out:
# 7090

# %%
df.head()
# Out:
#             snp_open  snp_high  snp_low  snp_close    snp_vol  snp_adjc  \
# Date
# 1987-01-02    242.17    246.45   242.17     246.45   91880000    246.45
# 1987-01-05    246.45    252.57   246.45     252.19  181900000    252.19
# 1987-01-06    252.20    253.99   252.14     252.78  189300000    252.78
# 1987-01-07    252.78    255.72   252.65     255.33  190900000    255.33
# 1987-01-08    255.36    257.28   254.97     257.28  194500000    257.28
#
#             intRate    dollar    gold    oil
# Date
# 1987-01-02     6.46  103.8142  403.50  18.13
# 1987-01-05     6.86  104.3439  398.95  17.98
# 1987-01-06     6.56  104.0379  401.70  18.21
# 1987-01-07     6.20  104.0810  400.40  18.28
# 1987-01-08     5.98  103.9592  402.65  18.63

# %%
dfX, y, yBin = make_Xy_shift(df, 'snp_close', 1)
len(dfX)
# Out:
# no nulls, dataframe length 7090
# 7089

# %%
def train_test_split_logreg_plot(X_data, y_data, info):
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=1)
    lr = LogisticRegression()
    lr.fit(X_train, y_train)
    preds = lr.predict(X_test)
    #lr.score(X_test, y_test)
    cm = metrics.confusion_matrix(y_test, preds)
    probs = lr.predict_proba(X_test)[:, 1]
    score = metrics.roc_auc_score(y_test, probs)
    plot_rocauc(y_test, probs) #, info)
    print lr.predict_proba(X_test)[:, 1].mean()

# %% [markdown]
# ### Using logistic regression with our new features added, we're still not doing awesome

# %%
train_test_split_logreg_plot(dfX, yBin, 'Using S&P data and forces')
# Out:
# 0.520089698531

# %%
df = (df - df.mean()) / (df.max() - df.min()) #consider log scaling
df.head()
checkpoint = df.copy()

# %%
#df = checkpoint.copy()

# %% [markdown]
# ### Plot all the normalized data so far to get a better idea for whats going on

# %%
def plot_lines(dframe, lines, info):
    plt.clf(); fig = plt.gcf()
    fig.set_size_inches(14, 6)
    width = len(lines)
    [plt.plot(dframe.index, dframe[i]) for i in lines]
    plt.legend(lines, loc='upper center', bbox_to_anchor=(0.3, 1),
               ncol=width, fancybox=True, shadow=True)
    plt.title(info)

# %%
lines = ['snp_close', 'intRate', 'dollar', 'gold', 'oil']
plot_lines(df, lines, "Normalized market data")

# %% [markdown]
# ### Generate and test derivatives as possible indicators

# %% [markdown]
# A fundamental aspect of spotting trends is being able to classify trends as positive or negative. One way to do this is by using a differential of rolling means. In finance, this calculation is reffered to as a "MACD" or moving average convergence/divergence. According to [Investopedia](http://www.investopedia.com/terms/m/macd.asp), a MACD is defined as:
# > "A trend-following momentum indicator that shows the relationship between two moving averages of prices."
# >
# > ![alt text](http://i.investopedia.com/inv/dictionary/terms/macd1.gif "macd chart")

# %% [markdown]
# ### Calculate a simple MACD with the long period set at 200 days and the short period set at 50 days

# %%
def find_smd(d, args):
    d = d.copy()
    smd = pd.stats.moments.rolling_mean(d, args[0]) - pd.stats.moments.rolling_mean(d, args[1])
    return smd

def rename_columns(d, label):
    d = d.copy()
    col = list(d.columns.values)     
    tag = [i + label for i in col] #for i in tickers]
    names = dict(zip(list(d.columns.values), tag))
    d.rename(columns=names, inplace=True)
    return d

# %%
#old
def make_df(d, fn, args, drop):
    dframe = d.copy()
    col = list(dframe.columns.values)
    for i in col:
        dt = dframe[i].copy()
        if drop:
            dt = dt.dropna()
        dt = fn(dt, args)
        dframe[i] = dt
    return dframe

# %%
df_smd = find_smd(df, [200,50])
lines = ['snp_close', 'intRate', 'dollar', 'gold', 'oil']
plot_lines(df_smd, lines, "Simple moving average differential: 200 vs 50 day")

# %%
df_smd = rename_columns(df_smd, '.smd')
df_smd.head()
# Out:
#             snp_open.smd  snp_high.smd  snp_low.smd  snp_close.smd  \
# Date
# 1987-01-02           NaN           NaN          NaN            NaN
# 1987-01-05           NaN           NaN          NaN            NaN
# 1987-01-06           NaN           NaN          NaN            NaN
# 1987-01-07           NaN           NaN          NaN            NaN
# 1987-01-08           NaN           NaN          NaN            NaN
#
#             snp_vol.smd  snp_adjc.smd  intRate.smd  dollar.smd  gold.smd  \
# Date
# 1987-01-02          NaN           NaN          NaN         NaN       NaN
# 1987-01-05          NaN           NaN          NaN         NaN       NaN
# 1987-01-06          NaN           NaN          NaN         NaN       NaN
# 1987-01-07          NaN           NaN          NaN         NaN       NaN
# 1987-01-08          NaN           NaN          NaN         NaN       NaN
#
#             oil.smd
# Date
# 1987-01-02      NaN
# 1987-01-05      NaN
# 1987-01-06      NaN
# 1987-01-07      NaN
# 1987-01-08      NaN

# %%
df_smd_join = df.join(df_smd, how='left')
df_smd_join.head()
# Out:
#             snp_open  snp_high   snp_low  snp_close   snp_vol  snp_adjc  \
# Date
# 1987-01-02 -0.380814 -0.381162 -0.377206  -0.377878 -0.142588 -0.377878
# 1987-01-05 -0.378529 -0.377899 -0.374921  -0.374819 -0.134720 -0.374819
# 1987-01-06 -0.375458 -0.377142 -0.371884  -0.374504 -0.134073 -0.374504
# 1987-01-07 -0.375148 -0.376220 -0.371611  -0.373145 -0.133934 -0.373145
# 1987-01-08 -0.373770 -0.375388 -0.370373  -0.372106 -0.133619 -0.372106
#
#              intRate    dollar      gold       oil  snp_open.smd  \
# Date
# 1987-01-02  0.253876  0.361226 -0.128444 -0.189967           NaN
# 1987-01-05  0.291365  0.372970 -0.131215 -0.191082           NaN
# 1987-01-06  0.263249  0.366186 -0.129540 -0.189372           NaN
# 1987-01-07  0.229509  0.367141 -0.130332 -0.188851           NaN
# 1987-01-08  0.208891  0.364441 -0.128961 -0.186249           NaN
#
#             snp_high.smd  snp_low.smd  snp_close.smd  snp_vol.smd  \
# Date
# 1987-01-02           NaN          NaN            NaN          NaN
# 1987-01-05           NaN          NaN            NaN          NaN
# 1987-01-06           NaN          NaN            NaN          NaN
# 1987-01-07           NaN          NaN            NaN          NaN
# 1987-01-08           NaN          NaN            NaN          NaN
#
#             snp_adjc.smd  intRate.smd  dollar.smd  gold.smd  oil.smd
# Date
# 1987-01-02           NaN          NaN         NaN       NaN      NaN
# 1987-01-05           NaN          NaN         NaN       NaN      NaN
# 1987-01-06           NaN          NaN         NaN       NaN      NaN
# 1987-01-07           NaN          NaN         NaN       NaN      NaN
# 1987-01-08           NaN          NaN         NaN       NaN      NaN

# %%
df_smd_join = kill_nulls(df_smd_join)
len(df_smd_join)
# Out:
# dropped these nulls:
# snp_open           0
# snp_high           0
# snp_low            0
# snp_close          0
# snp_vol            0
# snp_adjc           0
# intRate            0
# dollar             0
# gold               0
# oil                0
# snp_open.smd     199
# snp_high.smd     199
# snp_low.smd      199
# snp_close.smd    199
# snp_vol.smd      199
# snp_adjc.smd     199
# intRate.smd      199
# dollar.smd       199
# gold.smd         199
# oil.smd          199
# dtype: int64
# dataframe length went from 7090 to 6891
# 6891

# %% [markdown]
# ### Using logistic regression with our simple MACD features

# %%
dfX, y, yBin = make_Xy_shift(df_smd_join, 'snp_close', 1)
train_test_split_logreg_plot(dfX, yBin, 'Using S&P data and forces with SMD')
# Out:
# no nulls, dataframe length 6891
# 0.53056368409

# %%
oldBin = yBin

# %%
features = list(df_smd.columns.values)
train_test_split_logreg_plot(dfX[features], yBin, 'Using S&P data and forces with SMD')
# Out:
# 0.5311536537

# %%
features = ['snp_close.smd']
train_test_split_logreg_plot(dfX[features], yBin, 'Using S&P data and forces with SMD')
# Out:
# 0.530913135862

# %%
for i in list(df_smd_join.columns.values):
    train_test_split_logreg_plot(dfX[[i]], yBin, i)
    print i
# Out:
# 0.530729396247
# snp_open
# 0.530725953434
# snp_high
# 0.530726502173
# snp_low
# 0.530720556253
# snp_close
# 0.530759625977
# snp_vol
# 0.530720556253
# snp_adjc
# 0.530719585996
# intRate
# 0.530600086104
# dollar
# 0.530554145156
# gold
# 0.530799219288
# oil
# 0.530919868481
# snp_open.smd
# 0.530913545686
# snp_high.smd
# 0.530918133776
# snp_low.smd
# 0.530913135862
# snp_close.smd
# 0.530618809963
# snp_vol.smd
# 0.530913135862
# snp_adjc.smd
# 0.531222667661
# intRate.smd
# 0.530747894606
# dollar.smd
# 0.53072107048
# gold.smd
# 0.530822514995
# oil.smd

# %% [markdown]
# ### Calculating the exponentially weighted MACD with a long period of 26 days and a short period of 12 days

# %%
def find_emd(d, args):
    emd = pd.stats.moments.ewma(d , span=args[0], freq="D") - pd.stats.moments.ewma(d , span=args[1], freq="D")
    return emd

# %%
df_emd = make_df(df, find_emd, [26, 12], False)
plot_lines(df_emd, lines, "MACD differential: 26 vs. 12 day")

# %%
#Smoother for better visuals

def make_smooth(d, period):
    smooth = pd.stats.moments.rolling_mean(d, period)
    return smooth

# %%
df_emd_smooth = make_df(df_emd, make_smooth, 600, True)
plot_lines(df_emd_smooth, lines, "MACD differential: 26 vs. 12 day - smoothed")

# %%
df_emd = rename_columns(df_emd, '.emd')
df_emd.tail()
# Out:
#             snp_open.emd  snp_high.emd  snp_low.emd  snp_close.emd  \
# Date
# 2015-02-10     -0.001105     -0.001429    -0.002072      -0.002212
# 2015-02-11     -0.002240     -0.002161    -0.003136      -0.003082
# 2015-02-12     -0.003165     -0.003351    -0.004444      -0.004577
# 2015-02-13     -0.004655     -0.004606    -0.006130      -0.006058
# 2015-02-17     -0.006096     -0.005719    -0.007514      -0.007291
#
#             snp_vol.emd  snp_adjc.emd  intRate.emd  dollar.emd  gold.emd  \
# Date
# 2015-02-10    -0.004956     -0.002212     0.000045   -0.020205 -0.003299
# 2015-02-11    -0.002261     -0.003082     0.000001   -0.019486 -0.001509
# 2015-02-12    -0.001460     -0.004577    -0.000033   -0.018700 -0.000029
# 2015-02-13     0.001004     -0.006058    -0.000059   -0.017872  0.000645
# 2015-02-17     0.004078     -0.007291    -0.000079   -0.017019  0.002284
#
#              oil.emd
# Date
# 2015-02-10  0.002810
# 2015-02-11  0.000841
# 2015-02-12 -0.000710
# 2015-02-13 -0.001918
# 2015-02-17 -0.002842

# %% [markdown]
# ### Calculating Bollinger values with a 20 day rolling period

# %% [markdown]
# One way to measure volatility is to compare moving averages with the standard deviation of price changes. This method was popularized in the 80's by John Bollinger who subsequently copyrighted the term Bollinger Bands®. When a price goes above or below two standard deviations from the moving average price change, it is outside of an upper or lower band and considered overbought or oversold. According to [Investopedia](http://www.investopedia.com/terms/b/bollingerbands.asp), a Bollinger calculations are useful:
# > "Because standard deviation is a measure of volatility, Bollinger Bands® adjust themselves to the market conditions. When the markets become more volatile, the bands widen (move further away from the average), and during less volatile periods, the bands contract (move closer to the average). The tightening of the bands is often used by technical traders as an early indication that the volatility is about to increase sharply."
# >
# > ![alt text](http://i.investopedia.com/inv/dictionary/terms/bollingerband.gif "bollinger chart")

# %%
def find_bolval(d, span): #redo with ewma?
    ma = pd.stats.moments.rolling_mean(d, span)  
    ab = abs(d - ma)  
    sd = pd.stats.moments.rolling_std(ab, span)  
    bolval = (d - ma) / sd #bollinger value
    #bollinger bands
    #upper = ma + 2*sd  #if d>upper, overbought
    #lower = ma - 2*sd  #if d<lower, oversold
    #width = 4*sd       #band width is total volatility
    return bolval

# %%
df_bol = make_df(df, find_bolval, 20, True)
plot_lines(df_bol, lines, "Bollinger values: 20 day")

# %%
df_bol_smooth = make_df(df_bol, make_smooth, 600, True)
plot_lines(df_bol_smooth, lines, "Bollinger values: 20 day - smoothed")

# %%
df_bol = rename_columns(df_bol, '.bol')
df_bol.tail()

# %%
#Todo
#calculate indicators: RSI, MFI, Stochastic
#model indicators and compare

# %% [markdown]
# ### Joining together all the features we've calculated so far

# %%
#checkpoint = df.copy
df_blob = df.join(df_smd, how='left')

# %%
df_blob = df_blob.join(df_emd, how='left')

# %%
df_blob = df_blob.join(df_bol, how='left')

# %% [markdown]
# ### And adding in historical fed data: recession data, inflation rates, productivity rates and business unit costs

# %%
indicators
# Out:
#             FRED.RECPROUSM156N - Value  RATEINF.INFLATION_USA - CPI  \
# Date
# 1987-01-31                         NaN                        1.460
# 1987-02-01                        0.02                          NaN
# 1987-02-28                         NaN                        2.104
# 1987-03-01                        0.04                          NaN
# 1987-03-31                         NaN                        3.033
# 1987-04-01                        0.02                          NaN
# 1987-04-30                         NaN                        3.775
# 1987-05-01                        0.02                          NaN
# 1987-05-31                         NaN                        3.857
# 1987-06-01                        0.02                          NaN
# 1987-06-30                         NaN                        3.653
# 1987-07-01                        0.02                          NaN
# 1987-07-31                         NaN                        3.927
# 1987-08-01                        0.06                          NaN
# 1987-08-31                         NaN                        4.284
# 1987-09-01                        0.06                          NaN
# 1987-09-30                         NaN                        4.356
# 1987-10-01                        0.00                          NaN
# 1987-10-31                         NaN                        4.533
# 1987-11-01                        0.06                          NaN
# 1987-11-30                         NaN                        4.529
# 1987-12-01                        0.08                          NaN
# 1987-12-31                         NaN                        4.434
# 1988-01-01                        0.16                          NaN
# 1988-01-31                         NaN                        4.047
# 1988-02-01                        0.04                          NaN
# 1988-02-29                         NaN                        3.943
# 1988-03-01                        0.00                          NaN
# 1988-03-31                         NaN                        3.925
# 1988-04-01                        0.10                          NaN
# ...                                ...                          ...
# 2013-09-01                        0.02                          NaN
# 2013-09-30                         NaN                        1.185
# 2013-10-01                        0.06                          NaN
# 2013-10-31                         NaN                        0.964
# 2013-11-01                        0.02                          NaN
# 2013-11-30                         NaN                        1.237
# 2013-12-01                        0.20                          NaN
# 2013-12-31                         NaN                        1.502
# 2014-01-01                        0.32                          NaN
# 2014-01-31                         NaN                        1.579
# 2014-02-01                        0.00                          NaN
# 2014-02-28                         NaN                        1.126
# 2014-03-01                        0.02                          NaN
# 2014-03-31                         NaN                        1.512
# 2014-04-01                        0.12                          NaN
# 2014-04-30                         NaN                        1.953
# 2014-05-01                        0.04                          NaN
# 2014-05-31                         NaN                        2.127
# 2014-06-01                        0.00                          NaN
# 2014-06-30                         NaN                        2.072
# 2014-07-01                        0.06                          NaN
# 2014-07-31                         NaN                        1.992
# 2014-08-01                        0.08                          NaN
# 2014-08-31                         NaN                        1.700
# 2014-09-01                        0.04                          NaN
# 2014-09-30                         NaN                        1.658
# 2014-10-01                        0.34                          NaN
# 2014-10-31                         NaN                        1.664
# 2014-11-30                         NaN                        1.322
# 2014-12-31                         NaN                        0.756
#
#             FRED.OPHNFB - Value  FRED.PRS88003203 - Value
# Date
# 1987-01-31                  NaN                       NaN
# 1987-02-01                  NaN                       NaN
# 1987-02-28                  NaN                       NaN
# 1987-03-01                  NaN                       NaN
# 1987-03-31                  NaN                       NaN
# 1987-04-01               61.802                    68.987
# 1987-04-30                  NaN                       NaN
# 1987-05-01                  NaN                       NaN
# 1987-05-31                  NaN                       NaN
# 1987-06-01                  NaN                       NaN
# 1987-06-30                  NaN                       NaN
# 1987-07-01               61.816                    68.865
# 1987-07-31                  NaN                       NaN
# 1987-08-01                  NaN                       NaN
# 1987-08-31                  NaN                       NaN
# 1987-09-01                  NaN                       NaN
# 1987-09-30                  NaN                       NaN
# 1987-10-01               62.349                    69.588
# 1987-10-31                  NaN                       NaN
# 1987-11-01                  NaN                       NaN
# 1987-11-30                  NaN                       NaN
# 1987-12-01                  NaN                       NaN
# 1987-12-31                  NaN                       NaN
# 1988-01-01               62.564                    69.668
# 1988-01-31                  NaN                       NaN
# 1988-02-01                  NaN                       NaN
# 1988-02-29                  NaN                       NaN
# 1988-03-01                  NaN                       NaN
# 1988-03-31                  NaN                       NaN
# 1988-04-01               62.735                    70.247
# ...                         ...                       ...
# 2013-09-01                  NaN                       NaN
# 2013-09-30                  NaN                       NaN
# 2013-10-01              106.572                   100.004
# 2013-10-31                  NaN                       NaN
# 2013-11-01                  NaN                       NaN
# 2013-11-30                  NaN                       NaN
# 2013-12-01                  NaN                       NaN
# 2013-12-31                  NaN                       NaN
# 2014-01-01              105.365                   101.442
# 2014-01-31                  NaN                       NaN
# 2014-02-01                  NaN                       NaN
# 2014-02-28                  NaN                       NaN
# 2014-03-01                  NaN                       NaN
# 2014-03-31                  NaN                       NaN
# 2014-04-01              106.112                   100.328
# 2014-04-30                  NaN                       NaN
# 2014-05-01                  NaN                       NaN
# 2014-05-31                  NaN                       NaN
# 2014-06-01                  NaN                       NaN
# 2014-06-30                  NaN                       NaN
# 2014-07-01              106.727                   100.385
# 2014-07-31                  NaN                       NaN
# 2014-08-01                  NaN                       NaN
# 2014-08-31                  NaN                       NaN
# 2014-09-01                  NaN                       NaN
# 2014-09-30                  NaN                       NaN
# 2014-10-01                  NaN                       NaN
# 2014-10-31                  NaN                       NaN
# 2014-11-30                  NaN                       NaN
# 2014-12-31                  NaN                       NaN
#
# [669 rows x 4 columns]

# %%
indicators = (indicators - indicators.mean()) / (indicators.max() - indicators.min()) #consider log scaling

# %%
col = list(indicators.columns.values)
tag = ['recession', 'inflation', 'productivity', 'unitCosts']
tags = dict(zip(col, tag))
print tags
# Out:
# {u'FRED.PRS88003203 - Value': 'unitCosts', u'FRED.RECPROUSM156N - Value': 'recession', u'FRED.OPHNFB - Value': 'productivity', u'RATEINF.INFLATION_USA - CPI': 'inflation'}

# %%
indicators.rename(columns=tags, inplace=True)
indicators.head()
# Out:
#             recession  inflation  productivity  unitCosts
# Date
# 1987-01-31        NaN  -0.159361           NaN        NaN
# 1987-02-01   -0.08352        NaN           NaN        NaN
# 1987-02-28        NaN  -0.082575           NaN        NaN
# 1987-03-01   -0.08332        NaN           NaN        NaN
# 1987-03-31        NaN   0.028192           NaN        NaN

# %% [markdown]
# ### And squishing it all together into one dataframe

# %%
df_blob = df_blob.join(indicators, how='left')
df_blob.tail()
# Out:
#             snp_open  snp_high   snp_low  snp_close   snp_vol  snp_adjc  \
# Date
# 2015-02-10  0.584323  0.591581  0.587088   0.593195  0.170138  0.593195
# 2015-02-11  0.594561  0.592978  0.592090   0.593163  0.163758  0.593163
# 2015-02-12  0.595324  0.601003  0.598490   0.603795  0.180495  0.603795
# 2015-02-13  0.605364  0.605535  0.607415   0.608330  0.157691  0.608330
# 2015-02-17  0.609471  0.607812  0.609070   0.610115  0.143209  0.610115
#
#              intRate    dollar      gold       oil    ...     snp_vol.bol  \
# Date                                                  ...
# 2015-02-10 -0.340313  0.039628  0.377585  0.069235    ...       -1.410895
# 2015-02-11 -0.340313  0.039628  0.371039  0.069235    ...       -1.627216
# 2015-02-12 -0.340313  0.039628  0.370277  0.069235    ...       -0.685806
# 2015-02-13 -0.340313  0.039628  0.376367  0.069235    ...       -1.858005
# 2015-02-17 -0.340313  0.039628  0.362361  0.069235    ...       -2.528819
#
#             snp_adjc.bol  intRate.bol  dollar.bol  gold.bol   oil.bol  \
# Date
# 2015-02-10      2.829114     0.370277    1.548338 -1.330710  3.308391
# 2015-02-11      2.599450     0.371840    1.282383 -1.757174  3.400741
# 2015-02-12      3.597716     0.373160    1.012378 -1.783859  3.211679
# 2015-02-13      3.971847     0.374555    0.765990 -1.331864  3.089066
# 2015-02-17      3.551284     0.416352    0.554541 -2.221070  2.946704
#
#             recession  inflation  productivity  unitCosts
# Date
# 2015-02-10        NaN        NaN           NaN        NaN
# 2015-02-11        NaN        NaN           NaN        NaN
# 2015-02-12        NaN        NaN           NaN        NaN
# 2015-02-13        NaN        NaN           NaN        NaN
# 2015-02-17        NaN        NaN           NaN        NaN
#
# [5 rows x 44 columns]

# %%
df_blob
# Out:
#             snp_open  snp_high   snp_low  snp_close   snp_vol  snp_adjc  \
# Date
# 1987-01-02 -0.380814 -0.381162 -0.377206  -0.377878 -0.142588 -0.377878
# 1987-01-05 -0.378529 -0.377899 -0.374921  -0.374819 -0.134720 -0.374819
# 1987-01-06 -0.375458 -0.377142 -0.371884  -0.374504 -0.134073 -0.374504
# 1987-01-07 -0.375148 -0.376220 -0.371611  -0.373145 -0.133934 -0.373145
# 1987-01-08 -0.373770 -0.375388 -0.370373  -0.372106 -0.133619 -0.372106
# 1987-01-09 -0.372756 -0.374364 -0.369764  -0.371333 -0.133750 -0.371333
# 1987-01-12 -0.371976 -0.373212 -0.368798  -0.370497 -0.134519 -0.370497
# 1987-01-13 -0.371132 -0.373698 -0.368110  -0.370683 -0.135682 -0.370683
# 1987-01-14 -0.371319 -0.372487 -0.367891  -0.369250 -0.131897 -0.369250
# 1987-01-15 -0.369877 -0.370376 -0.366279  -0.367731 -0.128497 -0.367731
# 1987-01-16 -0.368376 -0.370077 -0.365387  -0.367310 -0.131530 -0.367310
# 1987-01-19 -0.367949 -0.368958 -0.365553  -0.365679 -0.136390 -0.365679
# 1987-01-20 -0.366304 -0.368057 -0.363604  -0.365839 -0.130971 -0.365839
# 1987-01-21 -0.366464 -0.368142 -0.363764  -0.366478 -0.134519 -0.366478
# 1987-01-22 -0.367105 -0.366446 -0.363780  -0.363244 -0.134126 -0.363244
# 1987-01-23 -0.363864 -0.362762 -0.363199  -0.365274 -0.124188 -0.365274
# 1987-01-26 -0.365898 -0.368393 -0.363562  -0.365535 -0.138478 -0.365535
# 1987-01-27 -0.366160 -0.366308 -0.362558  -0.363329 -0.133811 -0.363329
# 1987-01-28 -0.363949 -0.365561 -0.360732  -0.362449 -0.133505 -0.362449
# 1987-01-29 -0.363068 -0.364953 -0.360994  -0.363068 -0.132675 -0.363068
# 1987-01-30 -0.363687 -0.366345 -0.361613  -0.363153 -0.136337 -0.363153
# 1987-02-02 -0.363773 -0.364687 -0.360663  -0.361890 -0.135113 -0.361890
# 1987-02-03 -0.362507 -0.364431 -0.359232  -0.362135 -0.133304 -0.362135
# 1987-02-04 -0.362753 -0.363461 -0.359494  -0.360190 -0.131180 -0.360190
# 1987-02-05 -0.360804 -0.362069 -0.357727  -0.359380 -0.128182 -0.359380
# 1987-02-06 -0.359992 -0.362320 -0.357081  -0.359977 -0.134528 -0.359977
# 1987-02-09 -0.360590 -0.363253 -0.358485  -0.360979 -0.138094 -0.360979
# 1987-02-10 -0.361594 -0.364255 -0.360487  -0.362625 -0.135909 -0.362625
# 1987-02-11 -0.363244 -0.364495 -0.359836  -0.361309 -0.135550 -0.361309
# 1987-02-12 -0.361925 -0.364319 -0.360273  -0.362332 -0.133103 -0.362332
# ...              ...       ...       ...        ...       ...       ...
# 2015-01-05  0.587025  0.582827  0.570391   0.567609  0.181436  0.567609
# 2015-01-06  0.569781  0.569929  0.557099   0.558032  0.239209  0.558032
# 2015-01-07  0.560916  0.569588  0.564097   0.570444  0.181992  0.570444
# 2015-01-08  0.574299  0.587966  0.577474   0.589757  0.193226  0.589757
# 2015-01-09  0.591837  0.588153  0.581595   0.580522  0.143418  0.580522
# 2015-01-12  0.582587  0.580086  0.573188   0.571702  0.151487  0.571702
# 2015-01-13  0.574817  0.584154  0.565538   0.568914  0.208372  0.568914
# 2015-01-14  0.567778  0.563611  0.554964   0.562647  0.232091  0.562647
# 2015-01-15  0.565295  0.565184  0.556581   0.552735  0.223180  0.552735
# 2015-01-16  0.553813  0.564709  0.554793   0.566991  0.203924  0.566991
# 2015-01-20  0.569038  0.569230  0.563531   0.568659  0.194129  0.568659
# 2015-01-21  0.568734  0.574216  0.567562   0.573759  0.175401  0.573759
# 2015-01-22  0.576270  0.588254  0.575216   0.590296  0.214381  0.590296
# 2015-01-23  0.591586  0.587380  0.588113   0.584258  0.161721  0.584258
# 2015-01-26  0.584878  0.584522  0.583005   0.587066  0.152299  0.587066
# 2015-01-27  0.583511  0.579318  0.571763   0.572389  0.140417  0.572389
# 2015-01-28  0.575223  0.576455  0.561930   0.557792  0.204896  0.557792
# 2015-01-29  0.559260  0.566938  0.555359   0.567966  0.210106  0.567966
# 2015-01-30  0.568285  0.566234  0.557601   0.553971  0.246073  0.553971
# 2015-02-02  0.556173  0.565349  0.550939   0.567753  0.199722  0.567753
# 2015-02-03  0.570080  0.580619  0.573257   0.583304  0.252825  0.583304
# 2015-02-04  0.584045  0.582987  0.580736   0.578763  0.211398  0.578763
# 2015-02-05  0.581156  0.587684  0.584328   0.589960  0.183435  0.589960
# 2015-02-06  0.591212  0.592403  0.587809   0.586203  0.219356  0.586203
# 2015-02-09  0.586507  0.583744  0.583490   0.581550  0.159622  0.581550
# 2015-02-10  0.584323  0.591581  0.587088   0.593195  0.170138  0.593195
# 2015-02-11  0.594561  0.592978  0.592090   0.593163  0.163758  0.593163
# 2015-02-12  0.595324  0.601003  0.598490   0.603795  0.180495  0.603795
# 2015-02-13  0.605364  0.605535  0.607415   0.608330  0.157691  0.608330
# 2015-02-17  0.609471  0.607812  0.609070   0.610115  0.143209  0.610115
#
#              intRate    dollar      gold       oil    ...     snp_vol.bol  \
# Date                                                  ...
# 1987-01-02  0.253876  0.361226 -0.128444 -0.189967    ...             NaN
# 1987-01-05  0.291365  0.372970 -0.131215 -0.191082    ...             NaN
# 1987-01-06  0.263249  0.366186 -0.129540 -0.189372    ...             NaN
# 1987-01-07  0.229509  0.367141 -0.130332 -0.188851    ...             NaN
# 1987-01-08  0.208891  0.364441 -0.128961 -0.186249    ...             NaN
# 1987-01-09  0.204204  0.362887 -0.129357 -0.185133    ...             NaN
# 1987-01-12  0.231383  0.341454 -0.123816 -0.183498    ...             NaN
# 1987-01-13  0.228572  0.333160 -0.125095 -0.184539    ...             NaN
# 1987-01-14  0.200456  0.302607 -0.121380 -0.182531    ...             NaN
# 1987-01-15  0.211702  0.307890 -0.120680 -0.182828    ...             NaN
# 1987-01-16  0.207953  0.306741 -0.121015 -0.182531    ...             NaN
# 1987-01-19  0.207953  0.306741 -0.117026 -0.185728    ...             NaN
# 1987-01-20  0.222949  0.298030 -0.120984 -0.185505    ...             NaN
# 1987-01-21  0.217325  0.306460 -0.126191 -0.186472    ...             NaN
# 1987-01-22  0.218263  0.282985 -0.124212 -0.185282    ...             NaN
# 1987-01-23  0.212639  0.294685 -0.130575 -0.186546    ...             NaN
# 1987-01-26  0.223886  0.288118 -0.126922 -0.186249    ...             NaN
# 1987-01-27  0.224823  0.272179 -0.123572 -0.187364    ...             NaN
# 1987-01-28  0.257625  0.263366 -0.122202 -0.186769    ...             NaN
# 1987-01-29  0.231383  0.266382 -0.124668 -0.185877    ...             NaN
# 1987-01-30  0.237007  0.292552 -0.130271 -0.185505    ...             NaN
# 1987-02-02  0.238881  0.274882 -0.126465 -0.186546    ...             NaN
# 1987-02-03  0.229509  0.269978 -0.128139 -0.188108    ...             NaN
# 1987-02-04  0.207953  0.274257 -0.128870 -0.189000    ...             NaN
# 1987-02-05  0.206079  0.291448 -0.131245 -0.186769    ...             NaN
# 1987-02-06  0.217325  0.303050 -0.128992 -0.187662    ...             NaN
# 1987-02-09  0.237944  0.279509 -0.126982 -0.188182    ...             NaN
# 1987-02-10  0.241693  0.268661 -0.128840 -0.187736    ...             NaN
# 1987-02-11  0.226697  0.286655 -0.128748 -0.190710    ...             NaN
# 1987-02-12  0.231383  0.293372 -0.129175 -0.190561    ...             NaN
# ...              ...       ...       ...       ...    ...             ...
# 2015-01-05 -0.340313 -0.028275  0.356576  0.047375    ...        0.269036
# 2015-01-06 -0.340313 -0.031977  0.362818  0.031983    ...        1.244167
# 2015-01-07 -0.340313 -0.016675  0.362970  0.037262    ...        0.205097
# 2015-01-08 -0.340313 -0.018777  0.366015  0.038080    ...        0.395399
# 2015-01-09 -0.340313 -0.020777  0.367385  0.034734    ...       -0.391164
# 2015-01-12 -0.340313 -0.018293  0.372713  0.017707    ...       -0.217959
# 2015-01-13 -0.340313 -0.014181  0.375758  0.016666    ...        0.710562
# 2015-01-14 -0.340313 -0.019921  0.377889  0.035775    ...        1.094017
# 2015-01-15 -0.340313 -0.017023  0.392504  0.020012    ...        1.000602
# 2015-01-16 -0.339376 -0.011538  0.403769  0.035775    ...        0.747124
# 2015-01-20 -0.340313 -0.004474  0.410620  0.023135    ...        0.635575
# 2015-01-21 -0.340313  0.005525  0.413512  0.031016    ...        0.614778
# 2015-01-22 -0.340313  0.017840  0.414882  0.016740    ...        1.282534
# 2015-01-23 -0.340313  0.030345  0.414273  0.011759    ...        0.243946
# 2015-01-26 -0.340313  0.032957  0.406053  0.008338    ...       -0.114488
# 2015-01-27 -0.341250  0.024277  0.410467  0.016071    ...       -0.712232
# 2015-01-28 -0.340313  0.029196  0.410163  0.002985    ...        1.136788
# 2015-01-29 -0.341250  0.046363  0.398441  0.003282    ...        1.251127
# 2015-01-30 -0.345936  0.048578  0.393265  0.030570    ...        2.614849
# 2015-02-02 -0.340313  0.038803  0.400724  0.041426    ...        0.318929
# 2015-02-03 -0.340313  0.024232  0.395701  0.069607    ...        2.618626
# 2015-02-04 -0.341250  0.031079  0.398289  0.035478    ...        0.795586
# 2015-02-05 -0.340313  0.022519  0.392656  0.050572    ...       -0.568975
# 2015-02-06 -0.341250  0.039628  0.381543  0.059346    ...        1.115504
# 2015-02-09 -0.340313  0.039628  0.380020  0.069235    ...       -1.842537
# 2015-02-10 -0.340313  0.039628  0.377585  0.069235    ...       -1.410895
# 2015-02-11 -0.340313  0.039628  0.371039  0.069235    ...       -1.627216
# 2015-02-12 -0.340313  0.039628  0.370277  0.069235    ...       -0.685806
# 2015-02-13 -0.340313  0.039628  0.376367  0.069235    ...       -1.858005
# 2015-02-17 -0.340313  0.039628  0.362361  0.069235    ...       -2.528819
#
#             snp_adjc.bol   intRate.bol  dollar.bol  gold.bol   oil.bol  \
# Date
# 1987-01-02           NaN           NaN         NaN       NaN       NaN
# 1987-01-05           NaN           NaN         NaN       NaN       NaN
# 1987-01-06           NaN           NaN         NaN       NaN       NaN
# 1987-01-07           NaN           NaN         NaN       NaN       NaN
# 1987-01-08           NaN           NaN         NaN       NaN       NaN
# 1987-01-09           NaN           NaN         NaN       NaN       NaN
# 1987-01-12           NaN           NaN         NaN       NaN       NaN
# 1987-01-13           NaN           NaN         NaN       NaN       NaN
# 1987-01-14           NaN           NaN         NaN       NaN       NaN
# 1987-01-15           NaN           NaN         NaN       NaN       NaN
# 1987-01-16           NaN           NaN         NaN       NaN       NaN
# 1987-01-19           NaN           NaN         NaN       NaN       NaN
# 1987-01-20           NaN           NaN         NaN       NaN       NaN
# 1987-01-21           NaN           NaN         NaN       NaN       NaN
# 1987-01-22           NaN           NaN         NaN       NaN       NaN
# 1987-01-23           NaN           NaN         NaN       NaN       NaN
# 1987-01-26           NaN           NaN         NaN       NaN       NaN
# 1987-01-27           NaN           NaN         NaN       NaN       NaN
# 1987-01-28           NaN           NaN         NaN       NaN       NaN
# 1987-01-29           NaN           NaN         NaN       NaN       NaN
# 1987-01-30           NaN           NaN         NaN       NaN       NaN
# 1987-02-02           NaN           NaN         NaN       NaN       NaN
# 1987-02-03           NaN           NaN         NaN       NaN       NaN
# 1987-02-04           NaN           NaN         NaN       NaN       NaN
# 1987-02-05           NaN           NaN         NaN       NaN       NaN
# 1987-02-06           NaN           NaN         NaN       NaN       NaN
# 1987-02-09           NaN           NaN         NaN       NaN       NaN
# 1987-02-10           NaN           NaN         NaN       NaN       NaN
# 1987-02-11           NaN           NaN         NaN       NaN       NaN
# 1987-02-12           NaN           NaN         NaN       NaN       NaN
# ...                  ...           ...         ...       ...       ...
# 2015-01-05     -1.543012 -7.987247e-02    4.198021  0.133416 -2.827274
# 2015-01-06     -2.265001 -7.849557e-02    3.432922  0.984091 -3.324209
# 2015-01-07     -1.021722 -7.732386e-02    4.121017  0.939598 -2.720645
# 2015-01-08      0.962328 -7.630534e-02    3.462296  1.639184 -2.314683
# 2015-01-09     -0.063293 -7.540448e-02    3.010155  2.225343 -2.238114
# 2015-01-12     -0.911169 -7.459847e-02    2.941796  3.037524 -2.960700
# 2015-01-13     -1.289907 -7.387487e-02    3.162394  3.212247 -2.995117
# 2015-01-14     -2.200439 -1.110702e-01    2.480754  3.170744 -1.835504
# 2015-01-15     -4.064725 -1.101999e-01    2.797513  4.142789 -3.054356
# 2015-01-16     -2.167077  6.317357e-01    3.350325  4.014630 -1.619300
# 2015-01-20     -1.837616 -7.450892e-02    3.972941  3.675026 -3.058961
# 2015-01-21     -0.958343 -3.730026e-02    4.736971  3.267653 -1.793712
# 2015-01-22      1.358404  7.510937e-13    5.349341  2.952672 -2.950664
# 2015-01-23      0.628029  3.730572e-02    5.388014  2.552452 -2.967376
# 2015-01-26      1.086662  7.462621e-02    4.804514  1.818127 -2.864669
# 2015-01-27     -0.652632 -5.972778e-01    3.714484  1.875763 -1.712286
# 2015-01-28     -2.328765  1.864890e-01    3.914812  1.689187 -2.573054
# 2015-01-29     -0.723095 -4.847836e-01    5.392403  0.836098 -2.162384
# 2015-01-30     -2.413626 -4.548859e+00    5.438970  0.387648  0.311303
# 2015-02-02     -0.397426  2.824177e-01    3.968582  0.672973  1.153628
# 2015-02-03      1.632407  2.830824e-01    1.810967  0.214114  3.140213
# 2015-02-04      0.924333 -4.866895e-01    2.071578  0.265672  0.684371
# 2015-02-05      2.388523  3.254332e-01    0.954145 -0.202149  1.848618
# 2015-02-06      1.872032 -4.491017e-01    2.138781 -0.990340  2.523456
# 2015-02-09      1.267941  3.688140e-01    1.838584 -1.146051  3.200852
# 2015-02-10      2.829114  3.702773e-01    1.548338 -1.330710  3.308391
# 2015-02-11      2.599450  3.718400e-01    1.282383 -1.757174  3.400741
# 2015-02-12      3.597716  3.731599e-01    1.012378 -1.783859  3.211679
# 2015-02-13      3.971847  3.745553e-01    0.765990 -1.331864  3.089066
# 2015-02-17      3.551284  4.163520e-01    0.554541 -2.221070  2.946704
#
#             recession  inflation  productivity  unitCosts
# Date
# 1987-01-02        NaN        NaN           NaN        NaN
# 1987-01-05        NaN        NaN           NaN        NaN
# 1987-01-06        NaN        NaN           NaN        NaN
# 1987-01-07        NaN        NaN           NaN        NaN
# 1987-01-08        NaN        NaN           NaN        NaN
# 1987-01-09        NaN        NaN           NaN        NaN
# 1987-01-12        NaN        NaN           NaN        NaN
# 1987-01-13        NaN        NaN           NaN        NaN
# 1987-01-14        NaN        NaN           NaN        NaN
# 1987-01-15        NaN        NaN           NaN        NaN
# 1987-01-16        NaN        NaN           NaN        NaN
# 1987-01-19        NaN        NaN           NaN        NaN
# 1987-01-20        NaN        NaN           NaN        NaN
# 1987-01-21        NaN        NaN           NaN        NaN
# 1987-01-22        NaN        NaN           NaN        NaN
# 1987-01-23        NaN        NaN           NaN        NaN
# 1987-01-26        NaN        NaN           NaN        NaN
# 1987-01-27        NaN        NaN           NaN        NaN
# 1987-01-28        NaN        NaN           NaN        NaN
# 1987-01-29        NaN        NaN           NaN        NaN
# 1987-01-30        NaN        NaN           NaN        NaN
# 1987-02-02        NaN        NaN           NaN        NaN
# 1987-02-03        NaN        NaN           NaN        NaN
# 1987-02-04        NaN        NaN           NaN        NaN
# 1987-02-05        NaN        NaN           NaN        NaN
# 1987-02-06        NaN        NaN           NaN        NaN
# 1987-02-09        NaN        NaN           NaN        NaN
# 1987-02-10        NaN        NaN           NaN        NaN
# 1987-02-11        NaN        NaN           NaN        NaN
# 1987-02-12        NaN        NaN           NaN        NaN
# ...               ...        ...           ...        ...
# 2015-01-05        NaN        NaN           NaN        NaN
# 2015-01-06        NaN        NaN           NaN        NaN
# 2015-01-07        NaN        NaN           NaN        NaN
# 2015-01-08        NaN        NaN           NaN        NaN
# 2015-01-09        NaN        NaN           NaN        NaN
# 2015-01-12        NaN        NaN           NaN        NaN
# 2015-01-13        NaN        NaN           NaN        NaN
# 2015-01-14        NaN        NaN           NaN        NaN
# 2015-01-15        NaN        NaN           NaN        NaN
# 2015-01-16        NaN        NaN           NaN        NaN
# 2015-01-20        NaN        NaN           NaN        NaN
# 2015-01-21        NaN        NaN           NaN        NaN
# 2015-01-22        NaN        NaN           NaN        NaN
# 2015-01-23        NaN        NaN           NaN        NaN
# 2015-01-26        NaN        NaN           NaN        NaN
# 2015-01-27        NaN        NaN           NaN        NaN
# 2015-01-28        NaN        NaN           NaN        NaN
# 2015-01-29        NaN        NaN           NaN        NaN
# 2015-01-30        NaN        NaN           NaN        NaN
# 2015-02-02        NaN        NaN           NaN        NaN
# 2015-02-03        NaN        NaN           NaN        NaN
# 2015-02-04        NaN        NaN           NaN        NaN
# 2015-02-05        NaN        NaN           NaN        NaN
# 2015-02-06        NaN        NaN           NaN        NaN
# 2015-02-09        NaN        NaN           NaN        NaN
# 2015-02-10        NaN        NaN           NaN        NaN
# 2015-02-11        NaN        NaN           NaN        NaN
# 2015-02-12        NaN        NaN           NaN        NaN
# 2015-02-13        NaN        NaN           NaN        NaN
# 2015-02-17        NaN        NaN           NaN        NaN
#
# [7090 rows x 44 columns]

# %%
df_blob[tag] = df_blob[tag].ffill()

# %%
df_blob['year'] = df_blob.index.year
df_blob['quarter'] = df_blob.index.quarter
df_blob['month'] = df_blob.index.month
df_blob['day'] = df_blob.index.dayofweek

# %% [markdown]
# ### Adding in a few more features: S&P percent change from open to close, a some binaries showing if the index is up or down for the day and whether or not it's in a streak, running up or down

# %%
df_blob['pChg'] = df_blob['snp_close'] / df_blob['snp_open'] - 1
df_blob['is_up'] = np.where(df_blob['snp_close'] > df_blob['snp_open'], 1, 0)
df_blob['is_run'] = np.where(df_blob['is_up'] == df_blob['is_up'].shift(1), 1, 0)

# %%
def show_runs(df, col):
    lastvalue = 0
    newcum = []
    for row in df.iterrows():
        thisvalue = row[1][col]
        if thisvalue > 0:
            thisvalue =  row[1][col] + lastvalue
        newcum.append( thisvalue )
        lastvalue = thisvalue    
    return newcum

df_blob['run'] = show_runs(df_blob, 'is_run')

df_blob.head(1)
# Out:
#             snp_open  snp_high   snp_low  snp_close   snp_vol  snp_adjc  \
# Date
# 1987-01-02 -0.380814 -0.381162 -0.377206  -0.377878 -0.142588 -0.377878
#
#              intRate    dollar      gold       oil    ...     productivity  \
# Date                                                  ...
# 1987-01-02  0.253876  0.361226 -0.128444 -0.189967    ...              NaN
#
#             unitCosts  year  month  day  quarter      pChg  is_up  is_run  run
# Date
# 1987-01-02        NaN  1987      1    4        1 -0.007711      1       0    0
#
# [1 rows x 52 columns]

# %%
df_blob['close_delta.vol'] = (df_blob['snp_close'] - df_blob['snp_close'].shift(1)) * df_blob['snp_vol']
df_blob.tail(1)
# Out:
#             snp_open  snp_high  snp_low  snp_close   snp_vol  snp_adjc  \
# Date
# 2015-02-17  0.609471  0.607812  0.60907   0.610115  0.143209  0.610115
#
#              intRate    dollar      gold       oil    ...     unitCosts  year  \
# Date                                                  ...
# 2015-02-17 -0.340313  0.039628  0.362361  0.069235    ...      0.431729  2015
#
#             month  day  quarter      pChg  is_up  is_run  run  close_delta.vol
# Date
# 2015-02-17      2    1        1  0.001057      1       1    2         0.000256
#
# [1 rows x 53 columns]

# %%
df_b = df_blob.copy()
df_b = kill_nulls(df_b)
len(df_b)
# Out:
# dropped these nulls:
# snp_open             0
# snp_high             0
# snp_low              0
# snp_close            0
# snp_vol              0
# snp_adjc             0
# intRate              0
# dollar               0
# gold                 0
# oil                  0
# snp_open.smd       199
# snp_high.smd       199
# snp_low.smd        199
# snp_close.smd      199
# snp_vol.smd        199
# snp_adjc.smd       199
# intRate.smd        199
# dollar.smd         199
# gold.smd           199
# oil.smd            199
# snp_open.emd         0
# snp_high.emd         0
# snp_low.emd          0
# snp_close.emd        0
# snp_vol.emd          0
# snp_adjc.emd         0
# intRate.emd          0
# dollar.emd           0
# gold.emd             0
# oil.emd              0
# snp_open.bol        38
# snp_high.bol        38
# snp_low.bol         38
# snp_close.bol       38
# snp_vol.bol         38
# snp_adjc.bol        38
# intRate.bol         38
# dollar.bol          38
# gold.bol            38
# oil.bol             38
# recession           62
# inflation           61
# productivity        62
# unitCosts           62
# year                 0
# month                0
# day                  0
# quarter              0
# pChg                 0
# is_up                0
# is_run               0
# run                  0
# close_delta.vol      1
# Length: 53, dtype: int64
# dataframe length went from 7090 to 6891
# 6891

# %% [markdown]
# ### Using logistic regression, our roc auc is still about 0.53

# %%
dfX, y, yBin = make_Xy_shift(df_b, 'snp_close', 1)
train_test_split_logreg_plot(dfX, yBin, 'Using blob')
# Out:
# no nulls, dataframe length 6891
# 0.531809985575

# %% [markdown]
# ### Using random forests

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
def train_test_split_clf_plot(X_data, y_data):
    col = list(X_data.columns.values)
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=1)
    clf = RandomForestClassifier(n_estimators=500, compute_importances=True, oob_score=True)
    clf.fit(X_train, y_train)
    preds = clf.predict(X_test)
    #lr.score(X_test, y_test)
    cm = metrics.confusion_matrix(y_test, preds)
    probs = clf.predict_proba(X_test)[:, 1]
    score = metrics.roc_auc_score(y_test, probs)
    prob_mean = clf.predict_proba(X_test)[:, 1].mean()
    plot_rocauc(y_test, probs) #, info, score, cm, col)
    print '%s' % (score)
    print cm
    fi = enumerate(clf.feature_importances_)
    cols = list(X_data.columns.values)
    #importance = dict(zip(cols, fi))
    results = [[value,cols[i]] for (i,value) in fi if value > 0.025]
    #best_cols = [cols[i]]
    #print importance
    return results
    #return best_cols
    return clf

# %% [markdown]
# ### We don't do much better

# %%
train_test_split_clf_plot(dfX, yBin) #, 'Using blob')
# Out:
# 0.533315177751
# [[382 540]
#  [421 724]]
# /Users/data/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.py:776: DeprecationWarning: Setting compute_importances is no longer required as version 0.14. Variable importances are now computed on the fly when accessing the feature_importances_ attribute. This parameter will be removed in 0.16.
#   DeprecationWarning)
# [[0.026513800326389024, 'snp_vol.emd'],
#  [0.025152115574918393, 'intRate.emd'],
#  [0.025045822587115428, 'snp_open.bol'],
#  [0.029594755455713623, 'snp_vol.bol'],
#  [0.030351434520036472, 'intRate.bol'],
#  [0.027934245830646885, 'dollar.bol'],
#  [0.027681697424680119, 'gold.bol'],
#  [0.027195499206446028, 'oil.bol'],
#  [0.027516225065077254, 'pChg'],
#  [0.027862717439734334, 'close_delta.vol']]

# %%
results = [[0.026513800326389024, 'snp_vol.emd'],
 [0.025152115574918393, 'intRate.emd'],
 [0.025045822587115428, 'snp_open.bol'],
 [0.029594755455713623, 'snp_vol.bol'],
 [0.030351434520036472, 'intRate.bol'],
 [0.027934245830646885, 'dollar.bol'],
 [0.027681697424680119, 'gold.bol'],
 [0.027195499206446028, 'oil.bol'],
 [0.027516225065077254, 'pChg'],
 [0.027862717439734334, 'close_delta.vol']]
best_cols = []
for i in range(1,len(results)):
    result = results[i][1]
    best_cols.append(result)
#best_cols = [best_cols.append(results[i][1]) for i in results]
best_cols.append('snp_close')
best_cols
# Out:
# ['intRate.emd',
#  'snp_open.bol',
#  'snp_vol.bol',
#  'intRate.bol',
#  'dollar.bol',
#  'gold.bol',
#  'oil.bol',
#  'pChg',
#  'close_delta.vol',
#  'snp_close']

# %%
df_b_refined = df_b[best_cols]
df_b_refined.head()
# Out:
#             intRate.emd  snp_open.bol  snp_vol.bol  intRate.bol  dollar.bol  \
# Date
# 1987-10-15    -0.012316     -3.249674     4.324780     0.805353   -3.238634
# 1987-10-16    -0.011210     -3.869069     4.376721    -0.082949   -2.896344
# 1987-10-19    -0.010664     -4.228819     4.462727     0.086965   -3.976723
# 1987-10-20    -0.006077     -4.467033     3.283809    -1.813072   -0.498083
# 1987-10-21     0.002071     -3.026347     1.732817    -3.275339   -0.312082
#
#             gold.bol   oil.bol      pChg  close_delta.vol  snp_close
# Date
# 1987-10-15  3.657271  1.544687  0.009260         0.000486  -0.350363
# 1987-10-16  2.676119  4.353624  0.021665         0.000992  -0.358559
# 1987-10-19  4.667736  0.934079  0.084153         0.003016  -0.389394
# 1987-10-20  0.677489  0.759352 -0.017816        -0.000623  -0.383005
# 1987-10-21  1.257440  1.743183 -0.031658        -0.001278  -0.371520

# %% [markdown]
# ### Refining to our most important 10 features, we do just a bit worse

# %%
dfX, y, yBin = make_Xy_shift(df_b_refined, 'snp_close', 1)
train_test_split_clf_plot(dfX, yBin) #, 'Using blob')
# Out:
# no nulls, dataframe length 6891
# 0.500406842918
# [[338 584]
#  [419 726]]
# /Users/data/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.py:776: DeprecationWarning: Setting compute_importances is no longer required as version 0.14. Variable importances are now computed on the fly when accessing the feature_importances_ attribute. This parameter will be removed in 0.16.
#   DeprecationWarning)
# [[0.099053216443369507, 'intRate.emd'],
#  [0.10257801282261031, 'snp_open.bol'],
#  [0.099415965263047759, 'snp_vol.bol'],
#  [0.10181847024308746, 'intRate.bol'],
#  [0.1019026537866923, 'dollar.bol'],
#  [0.10238706030837119, 'gold.bol'],
#  [0.098541135388648241, 'oil.bol'],
#  [0.09702294613845705, 'pChg'],
#  [0.098660785617290692, 'close_delta.vol'],
#  [0.098619753988425152, 'snp_close']]

# %% [markdown]
# ### Adjusting our prediction to 20 days out, we do much better

# %%
dfX, y, yBin = make_Xy_shift(df_b_refined, 'snp_close', 20)
train_test_split_clf_plot(dfX, yBin) #, 'Using blob')
# Out:
# no nulls, dataframe length 6891
# 0.821386796659
# [[ 393  380]
#  [ 107 1187]]
# /Users/data/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.py:776: DeprecationWarning: Setting compute_importances is no longer required as version 0.14. Variable importances are now computed on the fly when accessing the feature_importances_ attribute. This parameter will be removed in 0.16.
#   DeprecationWarning)
# [[0.11729479889961424, 'intRate.emd'],
#  [0.095285774859366179, 'snp_open.bol'],
#  [0.085334516694002119, 'snp_vol.bol'],
#  [0.090458135706687343, 'intRate.bol'],
#  [0.096806942937208873, 'dollar.bol'],
#  [0.098445362363970973, 'gold.bol'],
#  [0.095070148315476499, 'oil.bol'],
#  [0.08608126397267199, 'pChg'],
#  [0.079079751846326887, 'close_delta.vol'],
#  [0.156143304404675, 'snp_close']]

# %% [markdown]
# ### And even better at 30 days out

# %%
dfX, y, yBin = make_Xy_shift(df_b_refined, 'snp_close', 30)
train_test_split_clf_plot(dfX, yBin) #, 'Using blob')
# Out:
# no nulls, dataframe length 6891
# 0.842338807233
# [[ 408  365]
#  [ 111 1183]]
# /Users/data/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.py:776: DeprecationWarning: Setting compute_importances is no longer required as version 0.14. Variable importances are now computed on the fly when accessing the feature_importances_ attribute. This parameter will be removed in 0.16.
#   DeprecationWarning)
# [[0.12205781780046678, 'intRate.emd'],
#  [0.095102074345595866, 'snp_open.bol'],
#  [0.080035607246131457, 'snp_vol.bol'],
#  [0.085820152208536546, 'intRate.bol'],
#  [0.095189767846775186, 'dollar.bol'],
#  [0.088345150640283532, 'gold.bol'],
#  [0.09524156947078051, 'oil.bol'],
#  [0.082500094890877479, 'pChg'],
#  [0.080037182012404645, 'close_delta.vol'],
#  [0.17567058353814857, 'snp_close']]

# %% [markdown]
# ### And even better at 60 days out

# %%
dfX, y, yBin = make_Xy_shift(df_b_refined, 'snp_close', 60)
train_test_split_clf_plot(dfX, yBin) #, 'Using blob')
# Out:
# no nulls, dataframe length 6891
# 0.895674407908
# [[ 378  273]
#  [  73 1343]]
# /Users/data/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.py:776: DeprecationWarning: Setting compute_importances is no longer required as version 0.14. Variable importances are now computed on the fly when accessing the feature_importances_ attribute. This parameter will be removed in 0.16.
#   DeprecationWarning)
# [[0.13312833033214994, 'intRate.emd'],
#  [0.090429507322335984, 'snp_open.bol'],
#  [0.071725847998731856, 'snp_vol.bol'],
#  [0.079741051464781942, 'intRate.bol'],
#  [0.082742342127881785, 'dollar.bol'],
#  [0.082304391503791596, 'gold.bol'],
#  [0.08501509954464373, 'oil.bol'],
#  [0.076145629376404733, 'pChg'],
#  [0.074954780487278258, 'close_delta.vol'],
#  [0.22381301984199964, 'snp_close']]

# %% [markdown]
# ### And finally 90 days out

# %%
dfX, y, yBin = make_Xy_shift(df_b_refined, 'snp_close', 90)
train_test_split_clf_plot(dfX, yBin) #, 'Using blob')
# Out:
# no nulls, dataframe length 6891
# 0.914980503916
# [[ 393  237]
#  [  65 1372]]
# /Users/data/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.py:776: DeprecationWarning: Setting compute_importances is no longer required as version 0.14. Variable importances are now computed on the fly when accessing the feature_importances_ attribute. This parameter will be removed in 0.16.
#   DeprecationWarning)
# [[0.15144689231965469, 'intRate.emd'],
#  [0.082703239553079108, 'snp_open.bol'],
#  [0.062640377959599897, 'snp_vol.bol'],
#  [0.071295856370079028, 'intRate.bol'],
#  [0.073586058127080967, 'dollar.bol'],
#  [0.074901290864884326, 'gold.bol'],
#  [0.080076970941267728, 'oil.bol'],
#  [0.073313506856967595, 'pChg'],
#  [0.071295142853005353, 'close_delta.vol'],
#  [0.25874066415438124, 'snp_close']]

# %% [markdown]
# ### What's next: At this point we're just predicting the binary, whether or not stocks will be up or down. The next step will be predicting the expected magnitude of the up or down swings; adding in a feature that tracks sentiment (PsychSignal) testing other modeling methods; and possible weighting schemes.
